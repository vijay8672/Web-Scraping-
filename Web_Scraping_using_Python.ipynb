# %% [markdown]
# ## Web Scraping
#
# BeautifulSoup is a Python library for pulling data out of HTML and XML files. It works with parser to provide idiomatic ways of navigating, searching, and modifying the parse tree.

# %%
# !pip install beautifulsoup4

# %%
# !pip install requests

# %% [markdown]
# ### Importing Libraries useful for data scraping

# %%
import sys
import time
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %% [markdown]
# ### Try, Except
# Try-The try block lets you test a block of code for errors.
# Except - The except block lets you handle the error. The finally block lets you execute code, regardless of the result of the try- and except blocks.

# %% [markdown]
# ### Python sleep()
# The sleep() function suspends (waits) execution of the current thread for a given number of seconds.

# %%
try:

  page = requests.get('https://www.cricbuzz.com')

except Exception as e:
  error_type,error_obj,error_info = sys.exc_info()
  print('ERROR FOR LINK:', url)
  print(error_type,'Line:', error_info.tb_lineno)

time.sleep(2)
soup = BeautifulSoup(page.text, 'html.parser')
links = soup.find_all('div',attrs = {'class':'cb-nws-intr'})

# %%
page
# Out:
# <Response [200]>

# %%
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
for i in links:
  print(i.text)
  print('\n')
# Out:
# The hosts are expected to bite the bullet and drop an out-of-form Pujara for the second Test
#
#
# In the wake of the emergence of the Omicron variant in South Africa, Kohli said that a conversation has been initiated within the team and expected a clarity on the situation soon
#
#
# The 30-year-old replaces Tim Paine who opted for an indefinite break, having earlier stepped down from captaincy
#
#
#  While South Africa's cricket team have been to 15 World Cups and are yet to reach a final, their rugby side have won three of the seven World Cups that they've been to. Why?
#
#
# The middle order batter stitched a game-breaking stand with Embuldeniya
#
#
# Shoaib Malik and Imad Wasim also do not find a place in the squad for the three-match T20I series in Karachi
#
#
# CSK pick Ravindra Jadeja as their first pick ahead of MS Dhoni
#
#
# In the second half of a thoughtful interview, the departing Indian fielding coach talks about how he changed the team's mindset
#
#
# ...
